# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/Tricky%20Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lkjknkjnk
print("hello numpy")
# Out:
# hello numpy

# %%
print('pandas has to be start')
# Out:
# pandas has to be start

# %%
x=[1,2,3]
y=x
y.append(4)
print(x)
# Out:
# [1, 2, 3, 4]
