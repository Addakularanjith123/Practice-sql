# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/Python/Programs%20%26%20Topics%20/Normal_Program/Basic_python_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**<font color="blue"><b><h2 align="center">prime or not </font> (Check given number)**

# %%
#prime or not using while loop
n=int(input("enter n value"))
i=1
c=0
while(n>=i):
    if n%i==0:
        c=c+1
    i=i+1
# i=i+1 ##if we write this condition it will be outside of the while loop it gives continueous loop like object c will be keep on incrementing c=1,2,3,4,5,6,7.....(infinite loop)
if c==2:
    # print("the number",n",is prime")
    print("prime")
else:
    # print("the number",n,"is not a prime")
    print("not prime")

# %%
print("hello ranjiht")
