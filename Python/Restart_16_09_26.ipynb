# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/Python/Restart_16_09_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prime or not

# %%
n=int(input("emter value"))
i=1
c=0
while n>=i:
    if n%i==0:
        c=c+1
    i=i+1
if c==2:
    print("prime")
else:
    print("not prime")

# %%
##factorial of the given number

n=int(input("enter n value"))
i=1
fact=1
while n>i:
    n=n*i
    i=i+1
print(n)
