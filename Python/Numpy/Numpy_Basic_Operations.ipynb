# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/Python/Numpy/Numpy_Basic_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
n=np.arange(10)
n

# %%
rev_q1=np.array([10,12,9]) #lets assume this is revenue of (Jan,Feb,Mar) this is 1Dim array
print(rev_q1)
rev_q1.ndim #This method gets the diamensions

# %% [markdown]
# ### The element has to be same in the all list wheather its 2d or 3d and many more

# %%
# It gives the error because of the there is no equal no of element in the both arrays(i.e 1st has 3elements and 2nd has 8elements)
#n=np.array([[10,12,9],[8,15,3.44,2,33,44,232]])

# %%
#if the company has two quarter revenue
rev=np.array([[10,12,9],[8,15,3]]) #It is 2Dim Array #first quater[10,12,9]('Jan','Feb','Mar') and second quater[8,15,3]('Apr','May','June')
rev
# It is 2*3 matrix array(2 rows with 3columns)

# %% [markdown]
# ### printing with data type

# %%
rev[1,1]

# %%
#If we want to get the revenue of the Apr
print(rev[1,1])#first(1st) row and 1st element

# %%
rev[1,1] #printing with data type

# %%
rev

# %%
#if we want to change the particular index
rev[1,1]=22 #15 value changed to 22
rev

# %%
print(rev[1,1])

# %%
rev.dtype

# %%
#Explicitly specifing the type and copying the 1st array
rev=np.array([[10,12,9],[8,15,3]],dtype=float)

# %%
rev

# %%
rev.dtype #Previously it is int64 now its float64

# %%
rev.nbytes #each of the element occupies the 8byte or 64bits

# %%
n=np.array([[10,12,9,3,44,232],[8,15,3,44,2,3]])
n

# %%
n.ndim # It is 2 diamension of the array

# %%
np.sort(n)

# %%
n.itemsize #byte size of the each of the element i.e no of bytes occupies

# %%
n.size #total size of object or total no of elements

# %%
n.nbytes #there are total 8*12(total no of elements)

# %%
n.dtype

# %%
n.shape #It means no.of rows and columns i.e 2 rows and 6 columns

# %%
np.sort(n) #It will sort by individual arrays i.e by row wise

# %%
np.sort(n).ndim #after sorting diamensions

# %%
np.sort(n,axis=None) # it will sort all the elements into single row while axis is None

# %%
np.sort(n,axis=None).ndim #It is single diamension now because the axis is None

# %%
print(np.sort(n,axis=None))

# %% [markdown]
# ## Creating Numpy Array with zero's(0's)

# %%
np.zeros((2,3)) #creating a empty zero's numpy array

# %%
np.ones((4,5)) #creating a empty one's numpy array

# %%
np.arange(10) #it will create element upto 10

# %%
np.arange(10,20) # It will create an array between 10 to 19

# %%
np.arange(10,20,2) # creating an even array between 10 to 19 because the step is 2

# %%
np.linspace(10,20) #(linear space)equal space between 10 to 20 by default it will create for 50 elements

# %%
np.linspace(10,20,5) #It will create upto 5 elements with linear space between 10 to 20r

# %%
rev #Here 2 rows and 3 columns

# %%
rev.ndim

# %%
id(rev)

# %%
rev.ravel() #It just convert into the single row and it may not effect the original one like a view in the sql

# %%
id(rev.ravel())

# %%
rev.flatten() # It will return the new array

# %%
id(rev.flatten())

# %% [markdown]
# The diamensions will not change because with in the array we are modifing the shape

# %%
rev.reshape(3,2) #if we reshape the elements has to satisfied

# %%
rev.reshape(3,2).ndim

# %%
rev.reshape(3,3) #because the elements are not satisfied

# %%
rev.reshape(6,1)

# %%
rev.reshape(6,1).ndim

# %%
rev

# %%
rev.min()

# %%
rev.max()

# %%
rev.sum() #entire array

# %%
rev.sum(axis=1) #It will take by row level i.e(10+1+9,8+15+3)

# %%
rev.sum(axis=0) #It will take by column level i.e vertically

# %%
rev.sum(axis=None) #entire array

# %%
rev.sum(axis=-1) #It's just axis=Value then it is True ,if axis=0 then it is false

# %%
rev

# %%
for i in rev:
  print('row :->',i)

# %%
a=np.array([1,4,36])
a

# %%
np.sqrt(a)

# %%
np.square(a)

# %%
np.std(a)
