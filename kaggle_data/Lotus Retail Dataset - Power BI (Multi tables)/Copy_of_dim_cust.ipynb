# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/kaggle_data/Lotus%20Retail%20Dataset%20-%20Power%20BI%20(Multi%20tables)/Copy_of_dim_cust.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
dim_cust=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_customers.csv')

# %%
dim_cust.head()
# Out:
#   customer_id        full_name  gender  birth_date       phone  \
# 0    CUS01518  Mohamed Mansour    Male  1981-05-01  1158132110
# 1    CUS02370      Maged Lotfy    Male  2003-04-10  1281872177
# 2    CUS01962      Ahmed Hafez    Male  1971-05-03  1141856715
# 3    CUS00344       Hoda Fathy  Female  2000-05-19  1195645083
# 4    CUS02664    Hussein Lotfy    MALE  1998-12-26  1149528740
#
#                            email     city         region loyalty_tier  \
# 0  mohamed.mansour52@hotmail.com     Suez     Canal Zone       Bronze
# 1                            NaN  Zagazig     Nile Delta       Bronze
# 2      ahmed.hafez18@outlook.com     Giza  Greater Cairo         Gold
# 3       hoda.fathy26@outlook.com     Giza  Greater Cairo       Bronze
# 4      hussein.lotfy80@gmail.com    Tanta     Nile Delta       Bronze
#
#   registration_date
# 0        2020-12-19
# 1        2021-05-13
# 2        2023-09-26
# 3        2021-07-07
# 4        2022-10-05

# %%
dim_cust.shape
# Out:
# (3050, 10)

# %%
dim_cust.isnull()
# Out:
#       customer_id  full_name  gender  birth_date  phone  email   city  region  \
# 0           False      False   False       False  False  False  False   False
# 1           False      False   False       False  False   True  False   False
# 2           False      False   False       False  False  False  False   False
# 3           False      False   False       False  False  False  False   False
# 4           False      False   False       False  False  False  False   False
# ...           ...        ...     ...         ...    ...    ...    ...     ...
# 3045        False      False   False       False  False  False  False   False
# 3046        False      False   False       False  False  False  False   False
# 3047        False      False   False       False  False  False  False   False
# 3048        False      False   False       False  False  False  False   False
# 3049        False      False   False       False  False   True  False   False
#
# ...

# %%
dim_cust.columns
# Out:
# Index(['customer_id', 'full_name', 'gender', 'birth_date', 'phone', 'email',
#        'city', 'region', 'loyalty_tier', 'registration_date'],
#       dtype='object')

# %%
dim_cust.describe()
# Out:
#               phone
# count  3.050000e+03
# mean   1.154291e+09
# std    8.475046e+07
# min    1.010092e+09
# 25%    1.077888e+09
# 50%    1.153491e+09
# 75%    1.229041e+09
# max    1.299995e+09

# %%
dim_cust.isnull().sum()
# Out:
# customer_id            0
# full_name              0
# gender                 0
# birth_date             0
# phone                  0
# email                382
# city                   0
# region                 0
# loyalty_tier           0
# registration_date      0
# dtype: int64

# %%
dim_cust['email']
# Out:
# 0       mohamed.mansour52@hotmail.com
# 1                                 NaN
# 2           ahmed.hafez18@outlook.com
# 3            hoda.fathy26@outlook.com
# 4           hussein.lotfy80@gmail.com
#                     ...
# 3045          walid.ali72@outlook.com
# 3046            ola.gamal66@yahoo.com
# 3047         sara.gamal56@hotmail.com
# 3048      youssef.nasser5@hotmail.com
# 3049                              NaN
# Name: email, Length: 3050, dtype: object

# %%
dim_cust['email'].isnull()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 3045    False
# 3046    False
# 3047    False
# 3048    False
# 3049     True
# Name: email, Length: 3050, dtype: bool

# %%
print(dim_cust['email'].isnull().sum())
# Out:
# 382

# %% [markdown]
# There are 385 records of null values in the email column and there is no null values in the other columns

# %%
missing = dim_cust['email'].isna() #selecting the Nan indexes in the data frame

print(type(missing))
print(missing.head())
# Out:
# <class 'pandas.core.series.Series'>
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: email, dtype: bool

# %%
print(dim_cust.loc[missing, 'email']) #selecting the missing indexes and email
# Out:
# 1       NaN
# 24      NaN
# 28      NaN
# 30      NaN
# 35      NaN
#        ...
# 3004    NaN
# 3010    NaN
# 3011    NaN
# 3019    NaN
# 3049    NaN
# Name: email, Length: 382, dtype: object

# %%
print(dim_cust.index[missing])
# Out:
# Index([   1,   24,   28,   30,   35,   47,   51,   60,   82,  110,
#        ...
#        2937, 2939, 2962, 2974, 2986, 3004, 3010, 3011, 3019, 3049],
#       dtype='int64', length=382)

# %%
dim_cust.loc[missing, 'full_name'] #selecting missing indexes and full_name column
# Out:
# 1          Maged Lotfy
# 24         Tarek Lotfy
# 28          Omar Ahmed
# 30          Ahmed Zaki
# 35        Sherif Hamdy
#              ...
# 3004      Sherif Wahba
# 3010    Hassan Mansour
# 3011       Sara Khalil
# 3019       Hossam Zaki
# 3049      Samah Khalil
# Name: full_name, Length: 382, dtype: object

# %%
dim_cust.head()
# Out:
#   customer_id        full_name  gender  birth_date       phone  \
# 0    CUS01518  Mohamed Mansour    Male  1981-05-01  1158132110
# 1    CUS02370      Maged Lotfy    Male  2003-04-10  1281872177
# 2    CUS01962      Ahmed Hafez    Male  1971-05-03  1141856715
# 3    CUS00344       Hoda Fathy  Female  2000-05-19  1195645083
# 4    CUS02664    Hussein Lotfy    MALE  1998-12-26  1149528740
#
#                            email     city         region loyalty_tier  \
# 0  mohamed.mansour52@hotmail.com     Suez     Canal Zone       Bronze
# 1                            NaN  Zagazig     Nile Delta       Bronze
# 2      ahmed.hafez18@outlook.com     Giza  Greater Cairo         Gold
# 3       hoda.fathy26@outlook.com     Giza  Greater Cairo       Bronze
# 4      hussein.lotfy80@gmail.com    Tanta     Nile Delta       Bronze
#
#   registration_date
# 0        2020-12-19
# 1        2021-05-13
# 2        2023-09-26
# 3        2021-07-07
# 4        2022-10-05

# %%
missing = dim_cust['email'].isna() #storing missing values in 'missing' object like in data record 2 it true

random_numbers = pd.Series(
    np.random.randint(0, 100, size=missing.sum()), #np.random.randint(start, stop, size) here there are 382 missing records
    index=dim_cust.index[missing] #select only missing indexes of the data frame eg.0,1,2,3,4,5,6,7...only 1,3,7 indexes are missing the email(i.e has Nan values) then it will only select those indexes Index([1, 3, 7]).
).astype(str).str.zfill(2) #converting into string datpe because to append and str.zfill(2) it make every number only 2 string digit

dim_cust.loc[missing, 'email'] = (    #loc is used to select the row and columns  and Select the email column only where missing == True.
    dim_cust.loc[missing, 'full_name'] #take the full_name values from rows where missing is True, and put them into the email column of those same rows
        .str.strip() #removing the spaces like first and last spaces
        .str.lower() #converting them into lower case
        .str.replace(r'\s+', '.', regex=True) #r'\s+' (Find one or more whitespace characters.)
                                    #replacing space with '.(dot)' and + used for one or more white spaces like('Ranjith  Addakula) there are two space then it will give(ranjith.addakula)
    + random_numbers #adding the above object
    + '@outlook.com' #adding the fixed domain
)

# %%
print(dim_cust[['full_name', 'email']].head(5).to_string(index=False))
# Out:
#       full_name                         email
# Mohamed Mansour mohamed.mansour52@hotmail.com
#     Maged Lotfy     maged.lotfy79@outlook.com
#     Ahmed Hafez     ahmed.hafez18@outlook.com
#      Hoda Fathy      hoda.fathy26@outlook.com
#   Hussein Lotfy     hussein.lotfy80@gmail.com

# %%
print(dim_cust[['full_name', 'email']].head(50).to_string(index=False))
# Out:
#       full_name                         email
# Mohamed Mansour mohamed.mansour52@hotmail.com
#     Maged Lotfy     maged.lotfy79@outlook.com
#     Ahmed Hafez     ahmed.hafez18@outlook.com
#      Hoda Fathy      hoda.fathy26@outlook.com
#   Hussein Lotfy     hussein.lotfy80@gmail.com
#    Nour Mostafa    nour.mostafa72@hotmail.com
#     Hazem Hamdy     hazem.hamdy68@outlook.com
#  Fatima Ramadan  fatima.ramadan42@outlook.com
#     Ramy Farouk      ramy.farouk8@hotmail.com
#     Sherif Zaki      sherif.zaki7@hotmail.com
#   Bassem Farouk     bassem.farouk40@gmail.com
#    Hossam Fathy      hossam.fathy16@yahoo.com
#     Hoda Badawi       hoda.badawi40@yahoo.com
#   Ahmed Mostafa   ahmed.mostafa83@hotmail.com
#   Yasmin Khalil     yasmin.khalil15@gmail.com
#  Hussein Younis    hussein.younis30@yahoo.com
#    Ramy Ramadan      ramy.ramadan58@yahoo.com
#    Doha Shaaban      doha.shaaban46@gmail.com
#     Tarek Ragab       tarek.ragab11@gmail.com
# ...

# %%
dim_cust['email']
# Out:
# 0       mohamed.mansour52@hotmail.com
# 1           maged.lotfy79@outlook.com
# 2           ahmed.hafez18@outlook.com
# 3            hoda.fathy26@outlook.com
# 4           hussein.lotfy80@gmail.com
#                     ...
# 3045          walid.ali72@outlook.com
# 3046            ola.gamal66@yahoo.com
# 3047         sara.gamal56@hotmail.com
# 3048      youssef.nasser5@hotmail.com
# 3049       samah.khalil03@outlook.com
# Name: email, Length: 3050, dtype: object

# %%
dim_cust
# Out:
#      customer_id        full_name  gender  birth_date       phone  \
# 0       CUS01518  Mohamed Mansour    Male  1981-05-01  1158132110
# 1       CUS02370      Maged Lotfy    Male  2003-04-10  1281872177
# 2       CUS01962      Ahmed Hafez    Male  1971-05-03  1141856715
# 3       CUS00344       Hoda Fathy  Female  2000-05-19  1195645083
# 4       CUS02664    Hussein Lotfy    MALE  1998-12-26  1149528740
# ...          ...              ...     ...         ...         ...
# 3045    CUS01639        Walid Ali    Male  1994-05-01  1047701601
# 3046    CUS01096        Ola Gamal  Female  1977-02-13  1143030893
# 3047    CUS01131       Sara Gamal  Female  1975-03-01  1245499509
# 3048    CUS01295   Youssef Nasser    Male  1976-06-11  1194842464
# 3049    CUS00861     Samah Khalil  Female  1980-07-19  1039832632
#
#                               email             city         region  \
# 0     mohamed.mansour52@hotmail.com             Suez     Canal Zone
# ...

# %% [markdown]
# # Selecting email domain

# %%
dim_cust['email']
# Out:
# 0       mohamed.mansour52@hotmail.com
# 1           maged.lotfy79@outlook.com
# 2           ahmed.hafez18@outlook.com
# 3            hoda.fathy26@outlook.com
# 4           hussein.lotfy80@gmail.com
#                     ...
# 3045          walid.ali72@outlook.com
# 3046            ola.gamal66@yahoo.com
# 3047         sara.gamal56@hotmail.com
# 3048      youssef.nasser5@hotmail.com
# 3049       samah.khalil03@outlook.com
# Name: email, Length: 3050, dtype: object

# %%
dim_cust['email'].str.split('@').str[-1].nunique()
# Out:
# 4

# %%
dim_cust['email'].str.split('@').str[-1].dropna().unique()
# Out:
# array(['hotmail.com', 'outlook.com', 'gmail.com', 'yahoo.com'],
#       dtype=object)

# %%
df=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_customers.csv')

# %%
df
# Out:
#      customer_id        full_name  gender  birth_date       phone  \
# 0       CUS01518  Mohamed Mansour    Male  1981-05-01  1158132110
# 1       CUS02370      Maged Lotfy    Male  2003-04-10  1281872177
# 2       CUS01962      Ahmed Hafez    Male  1971-05-03  1141856715
# 3       CUS00344       Hoda Fathy  Female  2000-05-19  1195645083
# 4       CUS02664    Hussein Lotfy    MALE  1998-12-26  1149528740
# ...          ...              ...     ...         ...         ...
# 3045    CUS01639        Walid Ali    Male  1994-05-01  1047701601
# 3046    CUS01096        Ola Gamal  Female  1977-02-13  1143030893
# 3047    CUS01131       Sara Gamal  Female  1975-03-01  1245499509
# 3048    CUS01295   Youssef Nasser    Male  1976-06-11  1194842464
# 3049    CUS00861     Samah Khalil  Female  1980-07-19  1039832632
#
#                               email             city         region  \
# 0     mohamed.mansour52@hotmail.com             Suez     Canal Zone
# ...

# %%
df['email'].str.split('@').str[-1].nunique()
# Out:
# 4

# %%
l=df['email'].str.split('@').str[-1].dropna().unique()
l
# Out:
# array(['hotmail.com', 'outlook.com', 'gmail.com', 'yahoo.com'],
#       dtype=object)

# %%
df
# Out:
#      customer_id        full_name  gender  birth_date       phone  \
# 0       CUS01518  Mohamed Mansour    Male  1981-05-01  1158132110
# 1       CUS02370      Maged Lotfy    Male  2003-04-10  1281872177
# 2       CUS01962      Ahmed Hafez    Male  1971-05-03  1141856715
# 3       CUS00344       Hoda Fathy  Female  2000-05-19  1195645083
# 4       CUS02664    Hussein Lotfy    MALE  1998-12-26  1149528740
# ...          ...              ...     ...         ...         ...
# 3045    CUS01639        Walid Ali    Male  1994-05-01  1047701601
# 3046    CUS01096        Ola Gamal  Female  1977-02-13  1143030893
# 3047    CUS01131       Sara Gamal  Female  1975-03-01  1245499509
# 3048    CUS01295   Youssef Nasser    Male  1976-06-11  1194842464
# 3049    CUS00861     Samah Khalil  Female  1980-07-19  1039832632
#
#                               email             city         region  \
# 0     mohamed.mansour52@hotmail.com             Suez     Canal Zone
# ...

# %%
import numpy as np

missing = df['email'].isna()

domains = np.random.choice(
    ['hotmail.com', 'outlook.com', 'gmail.com', 'yahoo.com'],
    size=missing.sum()
)

random_numbers = np.random.randint(0, 100, size=missing.sum())

df.loc[missing, 'email'] = (
    df.loc[missing, 'full_name']
    .str.lower()
    .str.replace(' ', '.', regex=False)
    + np.char.zfill(random_numbers.astype(str), 2)
    + '@'
    + domains
)

# %%
df
# Out:
#      customer_id        full_name  gender  birth_date       phone  \
# 0       CUS01518  Mohamed Mansour    Male  1981-05-01  1158132110
# 1       CUS02370      Maged Lotfy    Male  2003-04-10  1281872177
# 2       CUS01962      Ahmed Hafez    Male  1971-05-03  1141856715
# 3       CUS00344       Hoda Fathy  Female  2000-05-19  1195645083
# 4       CUS02664    Hussein Lotfy    MALE  1998-12-26  1149528740
# ...          ...              ...     ...         ...         ...
# 3045    CUS01639        Walid Ali    Male  1994-05-01  1047701601
# 3046    CUS01096        Ola Gamal  Female  1977-02-13  1143030893
# 3047    CUS01131       Sara Gamal  Female  1975-03-01  1245499509
# 3048    CUS01295   Youssef Nasser    Male  1976-06-11  1194842464
# 3049    CUS00861     Samah Khalil  Female  1980-07-19  1039832632
#
#                               email             city         region  \
# 0     mohamed.mansour52@hotmail.com             Suez     Canal Zone
# ...

# %%
df_cust=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_customers.csv')

# %%
df_cust
# Out:
#      customer_id        full_name  gender  birth_date       phone  \
# 0       CUS01518  Mohamed Mansour    Male  1981-05-01  1158132110
# 1       CUS02370      Maged Lotfy    Male  2003-04-10  1281872177
# 2       CUS01962      Ahmed Hafez    Male  1971-05-03  1141856715
# 3       CUS00344       Hoda Fathy  Female  2000-05-19  1195645083
# 4       CUS02664    Hussein Lotfy    MALE  1998-12-26  1149528740
# ...          ...              ...     ...         ...         ...
# 3045    CUS01639        Walid Ali    Male  1994-05-01  1047701601
# 3046    CUS01096        Ola Gamal  Female  1977-02-13  1143030893
# 3047    CUS01131       Sara Gamal  Female  1975-03-01  1245499509
# 3048    CUS01295   Youssef Nasser    Male  1976-06-11  1194842464
# 3049    CUS00861     Samah Khalil  Female  1980-07-19  1039832632
#
#                               email             city         region  \
# 0     mohamed.mansour52@hotmail.com             Suez     Canal Zone
# ...

# %%
# import numpy as np

# missing = df_cust['email'].isna()

# domains = np.random.choice(
#     ['hotmail.com', 'outlook.com', 'gmail.com', 'yahoo.com'],
#     size=missing.sum()
# )

# phone_digits = df_cust.loc[missing, 'phone'].astype(str).apply(
#     lambda x: ''.join(np.random.choice(list(set(x)), 2, replace=False))
# )

# df_cust.loc[missing, 'email'] = (
#     df_cust.loc[missing, 'full_name']
#     .str.lower()
#     .str.replace(' ', '.', regex=False)
#     + phone_digits
#     + '@'
#     + domains
# )

# %%
df_cust
# Out:
#      customer_id        full_name  gender  birth_date       phone  \
# 0       CUS01518  Mohamed Mansour    Male  1981-05-01  1158132110
# 1       CUS02370      Maged Lotfy    Male  2003-04-10  1281872177
# 2       CUS01962      Ahmed Hafez    Male  1971-05-03  1141856715
# 3       CUS00344       Hoda Fathy  Female  2000-05-19  1195645083
# 4       CUS02664    Hussein Lotfy    MALE  1998-12-26  1149528740
# ...          ...              ...     ...         ...         ...
# 3045    CUS01639        Walid Ali    Male  1994-05-01  1047701601
# 3046    CUS01096        Ola Gamal  Female  1977-02-13  1143030893
# 3047    CUS01131       Sara Gamal  Female  1975-03-01  1245499509
# 3048    CUS01295   Youssef Nasser    Male  1976-06-11  1194842464
# 3049    CUS00861     Samah Khalil  Female  1980-07-19  1039832632
#
#                               email             city         region  \
# 0     mohamed.mansour52@hotmail.com             Suez     Canal Zone
# ...

# %%
df_cust['customer_id'].duplicated().any()
# Out:
# np.True_

# %%
df_cust[df_cust['customer_id'].duplicated()]
# Out:
#      customer_id       full_name  gender  birth_date       phone  \
# 432     CUS02610   Ahmed Mostafa    MALE  1974-03-02  1063360110
# 541     CUS00044       Adel Bakr    Male  1978-03-24  1195800828
# 807     CUS01993     Dalia Hamdy  Female  16/04/1993  1189684093
# 810     CUS01175  Youssef Younis    Male  1985-07-06  1267278051
# 926     CUS01721   Mariam Nasser  Female  1996-01-23  1190808054
# 956     CUS02224     Aisha Hafez  Female  1972-09-27  1225073447
# 1143    CUS02233     Ashraf Amin    male  1975-03-16  1140963485
# 1250    CUS02214     Radwa Lotfy  Female  1998-07-13  1148451635
# 1346    CUS02855       Hany Saad    Male  1996-02-12  1215604302
# 1357    CUS00899    Ramy Ibrahim    male  2003-04-27  1073753876
# 1428    CUS02462    Omar Mohamed    Male  1972-10-19  1185032591
# 1507    CUS00793      Samir Saad    Male  1981-07-25  1073516387
# 1559    CUS02655       Essam Ali    Male  1970-03-12  1086793020
# ...

# %%
df_cust['customer_id'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3045    False
# 3046    False
# 3047    False
# 3048    False
# 3049    False
# Name: customer_id, Length: 3050, dtype: bool

# %%
df_cust['customer_id'].duplicated().sum()
# Out:
# np.int64(50)

# %%
df_cust['customer_id'].value_counts().loc[lambda x: x > 1]
# Out:
# customer_id
# CUS02910    2
# CUS02036    2
# CUS02668    2
# CUS02855    2
# CUS00360    2
# CUS01114    2
# CUS00859    2
# CUS02467    2
# CUS02224    2
# CUS02698    2
# CUS02957    2
# CUS02214    2
# CUS00793    2
# CUS01246    2
# CUS02445    2
# CUS01260    2
# CUS02233    2
# CUS02462    2
# CUS01699    2
# CUS02265    2
# CUS01395    2
# CUS02865    2
# CUS01650    2
# CUS01736    2
# CUS02655    2
# CUS02645    2
# CUS01721    2
# CUS00001    2
# CUS02484    2
# CUS00105    2
# CUS02382    2
# CUS00044    2
# CUS00164    2
# CUS00579    2
# CUS01993    2
# CUS00731    2
# CUS01929    2
# CUS00803    2
# CUS02610    2
# CUS02053    2
# CUS02094    2
# CUS02051    2
# CUS02863    2
# CUS02311    2
# CUS02806    2
# CUS01175    2
# CUS01549    2
# CUS00684    2
# CUS00032    2
# CUS00899    2
# Name: count, dtype: int64

# %%
df=df_cust[df_cust['customer_id'].duplicated(keep=False)]

# %%
df
# Out:
#      customer_id       full_name  gender  birth_date       phone  \
# 16      CUS02863    Ramy Ramadan    Male  1989-05-22  1019329244
# 42      CUS00360      Heba Lotfy  Female  1989-08-02  1210626224
# 72      CUS02445      Nadia Amin  Female  1982-02-16  1231347320
# 108     CUS00001     Manar Hamdy  Female  1977-10-07  1283233096
# 165     CUS02957   Samir Mohamed    Male  1987-03-04  1011264861
# ...          ...             ...     ...         ...         ...
# 2858    CUS00684  Hassan Mansour    MALE  1975-12-03  1068112164
# 2940    CUS01699   Aisha Mahmoud  Female  1980-07-19  1217115675
# 2958    CUS02265      Ahmed Bakr    Male  2003-01-04  1085431973
# 3011    CUS01736     Sara Khalil  Female  1988-09-20  1157278097
# 3013    CUS02484   Sherif Younis    male  20/09/1980  1075866125
#
#                             email        city         region loyalty_tier  \
# 16       ramy.ramadan58@yahoo.com   Port Said     Canal Zone     Platinum
# ...

# %%
df=df_cust[df_cust['customer_id'].duplicated(keep=False)] \
.sort_values('customer_id')

# %%
duplicates = df_cust[df_cust['customer_id'].duplicated(keep=False)] \
               .sort_values('customer_id')

# %%
duplicates
# Out:
#      customer_id       full_name  gender  birth_date       phone  \
# 108     CUS00001     Manar Hamdy  Female  1977-10-07  1283233096
# 1641    CUS00001     Manar Hamdy  Female  1977-10-07  1283233096
# 577     CUS00032   Shaimaa Sayed  Female  1983-09-08  1176038997
# 1996    CUS00032   Shaimaa Sayed  Female  1983-09-08  1176038997
# 460     CUS00044       Adel Bakr    Male  1978-03-24  1195800828
# ...          ...             ...     ...         ...         ...
# 2464    CUS02865  Mohamed Ismail    Male  1993-08-05  1260507167
# 1977    CUS02910    Mona Mohamed  FEMALE  1975-11-24  1140195198
# 184     CUS02910    Mona Mohamed  FEMALE  1975-11-24  1140195198
# 1681    CUS02957   Samir Mohamed    Male  1987-03-04  1011264861
# 165     CUS02957   Samir Mohamed    Male  1987-03-04  1011264861
#
#                            email     city         region loyalty_tier  \
# 108      manar.hamdy91@yahoo.com     Giza  Greater Cairo       Silver
# ...

# %%
duplicates.value_counts() #does not count the NaN values
# Out:
# customer_id  full_name       gender  birth_date  phone       email                        city        region         loyalty_tier  registration_date
# CUS00001     Manar Hamdy     Female  1977-10-07  1283233096  manar.hamdy91@yahoo.com      Giza        Greater Cairo  Silver        2023-05-27           2
# CUS00032     Shaimaa Sayed   Female  1983-09-08  1176038997  shaimaa.sayed6@yahoo.com     Cairo       Greater Cairo  Bronze        2023-12-12           2
# CUS00044     Adel Bakr       Male    1978-03-24  1195800828  adel.bakr89@hotmail.com      Suez        Canal Zone     Gold          2021-11-19           2
# CUS00105     Hoda Salem      Female  1993-07-08  1249057246  hoda.salem2@yahoo.com        Suez        Canal Zone     Bronze        2021-09-05           2
# CUS00164     Dina Lotfy      Female  2003-11-20  1240524866  dina.lotfy78@hotmail.com     Alexandria  Alexandria     Bronze        2023-09-05           2
# ...

# %%
duplicates.sort_values('customer_id', na_position='last')
# Out:
#      customer_id       full_name  gender  birth_date       phone  \
# 108     CUS00001     Manar Hamdy  Female  1977-10-07  1283233096
# 1641    CUS00001     Manar Hamdy  Female  1977-10-07  1283233096
# 577     CUS00032   Shaimaa Sayed  Female  1983-09-08  1176038997
# 1996    CUS00032   Shaimaa Sayed  Female  1983-09-08  1176038997
# 460     CUS00044       Adel Bakr    Male  1978-03-24  1195800828
# ...          ...             ...     ...         ...         ...
# 2464    CUS02865  Mohamed Ismail    Male  1993-08-05  1260507167
# 1977    CUS02910    Mona Mohamed  FEMALE  1975-11-24  1140195198
# 184     CUS02910    Mona Mohamed  FEMALE  1975-11-24  1140195198
# 1681    CUS02957   Samir Mohamed    Male  1987-03-04  1011264861
# 165     CUS02957   Samir Mohamed    Male  1987-03-04  1011264861
#
#                            email     city         region loyalty_tier  \
# 108      manar.hamdy91@yahoo.com     Giza  Greater Cairo       Silver
# ...

# %%
duplicates['customer_id'].value_counts(dropna=False).sort_index()
# Out:
# customer_id
# CUS00001    2
# CUS00032    2
# CUS00044    2
# CUS00105    2
# CUS00164    2
# CUS00360    2
# CUS00579    2
# CUS00684    2
# CUS00731    2
# CUS00793    2
# CUS00803    2
# CUS00859    2
# CUS00899    2
# CUS01114    2
# CUS01175    2
# CUS01246    2
# CUS01260    2
# CUS01395    2
# CUS01549    2
# CUS01650    2
# CUS01699    2
# CUS01721    2
# CUS01736    2
# CUS01929    2
# CUS01993    2
# CUS02036    2
# CUS02051    2
# CUS02053    2
# CUS02094    2
# CUS02214    2
# CUS02224    2
# CUS02233    2
# CUS02265    2
# CUS02311    2
# CUS02382    2
# CUS02445    2
# CUS02462    2
# CUS02467    2
# CUS02484    2
# CUS02610    2
# CUS02645    2
# CUS02655    2
# CUS02668    2
# CUS02698    2
# CUS02806    2
# CUS02855    2
# CUS02863    2
# CUS02865    2
# CUS02910    2
# CUS02957    2
# Name: count, dtype: int64

# %%
df_cust=df_cust.drop_duplicates(subset=['customer_id'], keep='first')

# %%
df_cust
# Out:
#      customer_id        full_name  gender  birth_date       phone  \
# 0       CUS01518  Mohamed Mansour    Male  1981-05-01  1158132110
# 1       CUS02370      Maged Lotfy    Male  2003-04-10  1281872177
# 2       CUS01962      Ahmed Hafez    Male  1971-05-03  1141856715
# 3       CUS00344       Hoda Fathy  Female  2000-05-19  1195645083
# 4       CUS02664    Hussein Lotfy    MALE  1998-12-26  1149528740
# ...          ...              ...     ...         ...         ...
# 3045    CUS01639        Walid Ali    Male  1994-05-01  1047701601
# 3046    CUS01096        Ola Gamal  Female  1977-02-13  1143030893
# 3047    CUS01131       Sara Gamal  Female  1975-03-01  1245499509
# 3048    CUS01295   Youssef Nasser    Male  1976-06-11  1194842464
# 3049    CUS00861     Samah Khalil  Female  1980-07-19  1039832632
#
#                               email             city         region  \
# 0     mohamed.mansour52@hotmail.com             Suez     Canal Zone
# ...

# %%
from google.colab import files

df_cust.to_csv('dim_cust_final.csv', index=False)
files.download('dim_cust_final.csv')
