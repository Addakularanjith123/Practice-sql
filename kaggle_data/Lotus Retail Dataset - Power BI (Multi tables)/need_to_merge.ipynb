# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/kaggle_data/Lotus%20Retail%20Dataset%20-%20Power%20BI%20(Multi%20tables)/need_to_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd

# %%
dim_orders_2022_23=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/fact_orders_2022_2023.csv')

# %%
dim_orders_2022_23

# %%
dim_orders_2022_23.isna().sum()

# %%
dim_orders_2024=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/fact_orders_2024.csv')

# %%
dim_orders_2024

# %%
dim_orders_2024.isna().sum()

# %%
dim_orders=dim_orders_2022_23+dim_orders_2024

# %%
dim_orders.shape()

# %%
dim_orders = pd.concat(
    [dim_orders_2022_23, dim_orders_2024],
    ignore_index=True
)

# %%
dim_orders

# %%
dim_orders.isna().sum()

# %%
dim_orders['employee_id'].unique()

# %%
dim_orders['employee_id'].nunique()

# %%
dim_orders.isnull()

# %%
dim_orders.columns[dim_orders.isna().any()]

# %%
dim_orders[dim_orders.isna().any(axis=1)]

# %%
dim_orders

# %%
dim_orders.to_csv('fact_final_orders.csv', index=False)

from google.colab import files
files.download('fact_final_orders.csv')
