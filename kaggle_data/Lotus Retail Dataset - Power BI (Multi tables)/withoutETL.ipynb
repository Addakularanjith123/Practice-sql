# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/kaggle_data/Lotus%20Retail%20Dataset%20-%20Power%20BI%20(Multi%20tables)/withoutETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
dim_employees=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_employees.csv')

# %%
dim_employees
# Out:
#     employee_id first_name last_name  gender                    role  \
# 0       EMP0001      Ghada     Sayed  Female           Store Manager
# 1       EMP0002      Nadia       Ali  Female         Sales Associate
# 2       EMP0003      Samah   Mahmoud  Female         Sales Associate
# 3       EMP0004     Neveen    Ismail  Female           Store Manager
# 4       EMP0005      Samir   Mahmoud    Male      Department Manager
# ..          ...        ...       ...     ...                     ...
# 211     EMP0212      Karim  Abdallah    Male                 Cashier
# 212     EMP0213       Heba   Barakat  Female                 Cashier
# 213     EMP0214      Magdy     Wahba    Male  Senior Sales Associate
# 214     EMP0215       Engy     Gamal  Female         Sales Associate
# 215     EMP0216       Wael     Lotfy    Male                 Cashier
#
#      store_id   hire_date  monthly_salary_egp
# 0           1  2018-07-04               14235
# ...

# %%
dim_employees.isna().sum()
# Out:
# employee_id           0
# first_name            0
# last_name             0
# gender                0
# role                  0
# store_id              0
# hire_date             0
# monthly_salary_egp    0
# dtype: int64

# %%
dim_products=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_products.csv')

# %%
dim_products
# Out:
#     product_id      product_name_raw     category subcategory         brand  \
# 0      CLT0001   T-Shirt | Black | S     Clothing        Tops  Nile Fashion
# 1      CLT0002   T-Shirt | Black | M     Clothing        Tops  Nile Fashion
# 2      CLT0003   T-Shirt | Black | L     Clothing        Tops  Nile Fashion
# 3      CLT0004  T-Shirt | Black | XL     Clothing        Tops  Nile Fashion
# 4      CLT0005   T-Shirt | White | S     Clothing        Tops  Nile Fashion
# ..         ...                   ...          ...         ...           ...
# 340    ELC0341   Epson EcoTank L3250  Electronics    Printers         Epson
# 341    ELC0342     Canon PIXMA G3420  Electronics    Printers         Canon
# 342    ELC0343      Sony PS5 Console  Electronics      Gaming          Sony
# 343    ELC0344  Nintendo Switch OLED  Electronics      Gaming      Nintendo
# 344    ELC0345         Xbox Series S  Electronics      Gaming     Microsoft
#
# ...

# %%
dim_products.isna().sum()
# Out:
# product_id          0
# product_name_raw    0
# category            0
# subcategory         0
# brand               0
# unit_price_text     0
# unit_price          0
# unit_cost           0
# stock_qty           0
# is_active           0
# dtype: int64

# %%
dim_store=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_stores.csv')

# %%
dim_store
# Out:
#     store_id                    store_name             city        district  \
# 0          1     Lotus Cairo Festival City            Cairo       New Cairo
# 1          2           Lotus Mall of Egypt             Giza    Sheikh Zayed
# 2          3              Lotus City Stars            Cairo       Nasr City
# 3          4  Lotus Alexandria City Centre       Alexandria          Smouha
# 4          5             Lotus San Stefano       Alexandria     San Stefano
# 5          6      Lotus Mansoura Mega Mall         Mansoura     El Mansoura
# 6          7             Lotus Tanta Stars            Tanta        El Tanta
# 7          8             Lotus Aswan Plaza            Aswan        El Aswan
# 8          9              Lotus Luxor Mall            Luxor        El Luxor
# 9         10     Lotus Hurghada Waterfront         Hurghada       El Mamsha
# 10        11         Lotus Suez Canal Mall             Suez       El Arbain
# ...

# %%
dim_store.isna().sum()
# Out:
# store_id        0
# store_name      0
# city            0
# district        0
# region          0
# opening_year    0
# size_sqm        0
# store_type      0
# dtype: int64

# %%
dim_date=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_date.csv')

# %%
dim_date
# Out:
#        date_id   full_date  day  month month_name  quarter quarter_name  year  \
# 0     20220101  2022-01-01    1      1    January        1           Q1  2022
# 1     20220102  2022-01-02    2      1    January        1           Q1  2022
# 2     20220103  2022-01-03    3      1    January        1           Q1  2022
# 3     20220104  2022-01-04    4      1    January        1           Q1  2022
# 4     20220105  2022-01-05    5      1    January        1           Q1  2022
# ...        ...         ...  ...    ...        ...      ...          ...   ...
# 1091  20241227  2024-12-27   27     12   December        4           Q4  2024
# 1092  20241228  2024-12-28   28     12   December        4           Q4  2024
# 1093  20241229  2024-12-29   29     12   December        4           Q4  2024
# 1094  20241230  2024-12-30   30     12   December        4           Q4  2024
# 1095  20241231  2024-12-31   31     12   December        4           Q4  2024
#
# ...

# %%
dim_date.isna().sum()
# Out:
# date_id         0
# full_date       0
# day             0
# month           0
# month_name      0
# quarter         0
# quarter_name    0
# year            0
# day_of_week     0
# day_name        0
# is_weekend      0
# week_of_year    0
# is_ramadan      0
# dtype: int64

# %%
dim_date=dim_date.drop(['day','month'],axis=1)

# %%
dim_date
# Out:
#        date_id   full_date month_name  quarter quarter_name  year  \
# 0     20220101  2022-01-01    January        1           Q1  2022
# 1     20220102  2022-01-02    January        1           Q1  2022
# 2     20220103  2022-01-03    January        1           Q1  2022
# 3     20220104  2022-01-04    January        1           Q1  2022
# 4     20220105  2022-01-05    January        1           Q1  2022
# ...        ...         ...        ...      ...          ...   ...
# 1091  20241227  2024-12-27   December        4           Q4  2024
# 1092  20241228  2024-12-28   December        4           Q4  2024
# 1093  20241229  2024-12-29   December        4           Q4  2024
# 1094  20241230  2024-12-30   December        4           Q4  2024
# 1095  20241231  2024-12-31   December        4           Q4  2024
#
#       day_of_week   day_name  is_weekend  week_of_year  is_ramadan
# 0               6   Saturday           1            52           0
# ...

# %%
dim_date=dim_date.drop('is_ramadan',axis=1)

# %%
dim_date
# Out:
#        date_id   full_date month_name  quarter quarter_name  year  \
# 0     20220101  2022-01-01    January        1           Q1  2022
# 1     20220102  2022-01-02    January        1           Q1  2022
# 2     20220103  2022-01-03    January        1           Q1  2022
# 3     20220104  2022-01-04    January        1           Q1  2022
# 4     20220105  2022-01-05    January        1           Q1  2022
# ...        ...         ...        ...      ...          ...   ...
# 1091  20241227  2024-12-27   December        4           Q4  2024
# 1092  20241228  2024-12-28   December        4           Q4  2024
# 1093  20241229  2024-12-29   December        4           Q4  2024
# 1094  20241230  2024-12-30   December        4           Q4  2024
# 1095  20241231  2024-12-31   December        4           Q4  2024
#
#       day_of_week   day_name  is_weekend  week_of_year
# 0               6   Saturday           1            52
# 1               7     Sunday           0            52
# ...

# %%
dim_date=dim_date.drop(['month_name','quarter','year'],axis=1)

# %%
dim_date
# Out:
#        date_id   full_date quarter_name  day_of_week   day_name  is_weekend  \
# 0     20220101  2022-01-01           Q1            6   Saturday           1
# 1     20220102  2022-01-02           Q1            7     Sunday           0
# 2     20220103  2022-01-03           Q1            1     Monday           0
# 3     20220104  2022-01-04           Q1            2    Tuesday           0
# 4     20220105  2022-01-05           Q1            3  Wednesday           0
# ...        ...         ...          ...          ...        ...         ...
# 1091  20241227  2024-12-27           Q4            5     Friday           1
# 1092  20241228  2024-12-28           Q4            6   Saturday           1
# 1093  20241229  2024-12-29           Q4            7     Sunday           0
# 1094  20241230  2024-12-30           Q4            1     Monday           0
# 1095  20241231  2024-12-31           Q4            2    Tuesday           0
#
#       week_of_year
# 0               52
# ...
