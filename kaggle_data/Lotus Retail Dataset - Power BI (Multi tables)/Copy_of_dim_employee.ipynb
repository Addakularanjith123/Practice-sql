# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/kaggle_data/Lotus%20Retail%20Dataset%20-%20Power%20BI%20(Multi%20tables)/Copy_of_dim_employee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

orders = pd.read_csv("/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/fact_final_orders.csv")
employees = pd.read_csv("/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_employees.csv")

missing_ids = orders[
    ~orders['employee_id'].isin(employees['employee_id'])
]

missing_ids[['employee_id']]
# Out:
#       employee_id
# 19            NaN
# 75            NaN
# 81            NaN
# 112           NaN
# 162           NaN
# ...           ...
# 11861         NaN
# 11895         NaN
# 11929         NaN
# 11971         NaN
# 11982         NaN
#
# [632 rows x 1 columns]

# %%
missing_ids['employee_id'].unique()
# Out:
# array([nan], dtype=object)

# %%
print("Missing employee IDs:", missing_ids["employee_id"].nunique())
# Out:
# Missing employee IDs: 0

# %%
print(
    orders[orders["employee_id"].isna()][["order_id", "employee_id"]]
)
# Out:
#          order_id employee_id
# 19     ORD0009755         NaN
# 75     ORD0009837         NaN
# 81     ORD0007912         NaN
# 112    ORD0001830         NaN
# 162    ORD0004082         NaN
# ...           ...         ...
# 11861  ORD0002973         NaN
# 11895  ORD0009091         NaN
# 11929  ORD0008805         NaN
# 11971  ORD0001301         NaN
# 11982  ORD0008918         NaN
#
# [632 rows x 2 columns]

# %%
print(orders["employee_id"].dtype)
print(employees["employee_id"].dtype)
# Out:
# object
# object

# %%
orders["employee_id"] = orders["employee_id"].astype("string").str.strip()
employees["employee_id"] = employees["employee_id"].astype("string").str.strip()

# %%
missing_ids = orders[
    ~orders["employee_id"].isin(employees["employee_id"])
]

print(missing_ids[["employee_id"]].drop_duplicates())
# Out:
#    employee_id
# 19        <NA>

# %%
print(missing_ids[["employee_id"]].drop_duplicates())
# Out:
#    employee_id
# 19        <NA>

# %%
from google.colab import files

files.download("/content/fact_final_orders_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4660/1970448213.py in <cell line: 0>()
#       1 from google.colab import files
#       2
# ----> 3 files.download("/content/fact_final_orders_cleaned.csv")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/fact_final_orders_cleaned.csv

# %%
from google.colab import files

files.download("/content/fact_final_orders_cleaned.csv")

# %%
orders.to_csv("/content/fact_final_orders_cleaned.csv", index=False)

# %%
employees.to_csv("/content/dim_employees_cleaned.csv", index=False)

from google.colab import files
files.download("/content/dim_employees_cleaned.csv")

# %%
missing_ids['employee_id'].drop_duplicates()

# %%
print(
    orders[orders["employee_id"].isna()][["order_id", "employee_id"]]
)

# %%
orders["employee_id"] = orders["employee_id"].astype("string").str.strip()
employees["employee_id"] = employees["employee_id"].astype("string").str.strip()

# %%
missing_ids.shape[0]

# %%
orders[orders['employee_id'].isna()]

# %%
print(orders['employee_id'].dtype)
print(employees['employee_id'].dtype)

# %%
orders['employee_id'] = orders['employee_id'].astype('string').str.strip()
employees['employee_id'] = employees['employee_id'].astype('string').str.strip()

missing_ids = orders[
    ~orders['employee_id'].isin(employees['employee_id'])
]

missing_ids[['employee_id']].drop_duplicates()

# %%
~orders['employee_id'].isin(employees['employee_id'])

# %%
orders['employee_id'].isna().sum()

# %%
orders[orders['employee_id'].isna()]

# %%
df_dim_orders=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_order_details.csv')

# %%
df_dim_orders

# %%
df_dim_orders.describe()

# %%
df_dim_orders.info()

# %%
# df_dim_orders['']
