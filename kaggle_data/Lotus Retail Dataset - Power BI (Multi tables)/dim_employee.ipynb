# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/kaggle_data/Lotus%20Retail%20Dataset%20-%20Power%20BI%20(Multi%20tables)/dim_employee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

orders = pd.read_csv("/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/fact_final_orders.csv")
employees = pd.read_csv("/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_employees.csv")

missing_ids = orders[
    ~orders['employee_id'].isin(employees['employee_id'])
]

missing_ids[['employee_id']]
# Out:
#       employee_id
# 19            NaN
# 75            NaN
# 81            NaN
# 112           NaN
# 162           NaN
# ...           ...
# 11861         NaN
# 11895         NaN
# 11929         NaN
# 11971         NaN
# 11982         NaN
#
# [632 rows x 1 columns]

# %%
missing_ids['employee_id'].unique()
# Out:
# array([nan], dtype=object)

# %%
missing_ids['employee_id'].drop_duplicates()
# Out:
# 19    NaN
# Name: employee_id, dtype: object

# %%
missing_ids.shape[0]
# Out:
# 632

# %%
orders[orders['employee_id'].isna()]
# Out:
#          order_id  order_date   date_id customer_id  store_id employee_id  \
# 19     ORD0009755  2022-01-02  20220102    CUS00200         7         NaN
# 75     ORD0009837  2022-01-07  20220107    CUS00485        13         NaN
# 81     ORD0007912  2022-01-07  20220107    CUS00133         7         NaN
# 112    ORD0001830  2022-01-11  20220111    CUS01008         5         NaN
# 162    ORD0004082  2022-01-15  20220115    CUS00157        10         NaN
# ...           ...         ...       ...         ...       ...         ...
# 11861  ORD0002973  2024-12-18  20241218    CUS00846        11         NaN
# 11895  ORD0009091  2024-12-21  20241221    CUS01184         3         NaN
# 11929  ORD0008805  2024-12-25  20241225    CUS00826        15         NaN
# 11971  ORD0001301  2024-12-29  20241229    CUS01886         1         NaN
# 11982  ORD0008918  2024-12-30  20241230    CUS01015        15         NaN
#
#       payment_method order_status  total_revenue  total_cost
# 19       Credit Card    Completed          960.5       560.0
# 75     Vodafone Cash    Completed          935.0       560.0
# 81        Debit Card    Completed         3210.5      1610.0
# 112            Fawry    Completed         2232.0      1150.0
# 162            Fawry    Completed        16228.0     12620.0
# ...              ...          ...            ...         ...
# 11861     Debit Card    Completed         2242.0      1330.0
# 11895  Vodafone Cash    Cancelled          150.0        70.0
# 11929          Fawry    Completed         5865.0      4940.0
# 11971    Credit Card    Completed          368.0       220.0
# 11982           Cash    Completed          686.0       480.0
#
# [632 rows x 10 columns]

# %%
print(orders['employee_id'].dtype)
print(employees['employee_id'].dtype)
# Out:
# object
# object

# %%
orders['employee_id'] = orders['employee_id'].astype('string').str.strip()
employees['employee_id'] = employees['employee_id'].astype('string').str.strip()

missing_ids = orders[
    ~orders['employee_id'].isin(employees['employee_id'])
]

missing_ids[['employee_id']].drop_duplicates()
# Out:
#    employee_id
# 19        <NA>

# %%
~orders['employee_id'].isin(employees['employee_id'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11995    False
# 11996    False
# 11997    False
# 11998    False
# 11999    False
# Name: employee_id, Length: 12000, dtype: bool

# %%
orders['employee_id'].isna().sum()
# Out:
# np.int64(632)

# %%
orders[orders['employee_id'].isna()]
# Out:
#          order_id  order_date   date_id customer_id  store_id employee_id  \
# 19     ORD0009755  2022-01-02  20220102    CUS00200         7        <NA>
# 75     ORD0009837  2022-01-07  20220107    CUS00485        13        <NA>
# 81     ORD0007912  2022-01-07  20220107    CUS00133         7        <NA>
# 112    ORD0001830  2022-01-11  20220111    CUS01008         5        <NA>
# 162    ORD0004082  2022-01-15  20220115    CUS00157        10        <NA>
# ...           ...         ...       ...         ...       ...         ...
# 11861  ORD0002973  2024-12-18  20241218    CUS00846        11        <NA>
# 11895  ORD0009091  2024-12-21  20241221    CUS01184         3        <NA>
# 11929  ORD0008805  2024-12-25  20241225    CUS00826        15        <NA>
# 11971  ORD0001301  2024-12-29  20241229    CUS01886         1        <NA>
# 11982  ORD0008918  2024-12-30  20241230    CUS01015        15        <NA>
#
#       payment_method order_status  total_revenue  total_cost
# 19       Credit Card    Completed          960.5       560.0
# 75     Vodafone Cash    Completed          935.0       560.0
# 81        Debit Card    Completed         3210.5      1610.0
# 112            Fawry    Completed         2232.0      1150.0
# 162            Fawry    Completed        16228.0     12620.0
# ...              ...          ...            ...         ...
# 11861     Debit Card    Completed         2242.0      1330.0
# 11895  Vodafone Cash    Cancelled          150.0        70.0
# 11929          Fawry    Completed         5865.0      4940.0
# 11971    Credit Card    Completed          368.0       220.0
# 11982           Cash    Completed          686.0       480.0
#
# [632 rows x 10 columns]

# %%
df_dim_orders=pd.read_csv('/content/drive/MyDrive/Kaggle datasets/Lotus Retail Dataset - Power BI (Multi tables)/dim_order_details.csv')

# %%
df_dim_orders
# Out:
#         detail_id    order_id product_id  quantity  unit_price  discount_pct  \
# 0      DTL0000001  ORD0000001    CLT0168         1         460            10
# 1      DTL0000002  ORD0000001    CLT0248         1         210            25
# 2      DTL0000003  ORD0000001    CLT0198         1         240             0
# 3      DTL0000004  ORD0000001    CLT0167         1         450             0
# 4      DTL0000005  ORD0000002    CLT0157         2         830             0
# ...           ...         ...        ...       ...         ...           ...
# 25094  DTL0025095  ORD0011998    CLT0223         1         100             0
# 25095  DTL0025096  ORD0011999    ELC0310         4        6500             0
# 25096  DTL0025097  ORD0011999    CLT0224         1         100             0
# 25097  DTL0025098  ORD0011999    CLT0184         1         620             5
# 25098  DTL0025099  ORD0012000    CLT0069         4         310             0
#
#        selling_price  unit_cost  line_total_revenue  line_total_cost
# 0              414.0        220               414.0              220
# 1              157.5        100               157.5              100
# 2              240.0        110               240.0              110
# 3              450.0        220               450.0              220
# 4              830.0        410              1660.0              820
# ...              ...        ...                 ...              ...
# 25094          100.0         40               100.0               40
# 25095         6500.0       5200             26000.0            20800
# 25096          100.0         40               100.0               40
# 25097          589.0        300               589.0              300
# 25098          310.0        150              1240.0              600
#
# [25099 rows x 10 columns]

# %%
df_dim_orders.describe()
# Out:
#            quantity    unit_price  discount_pct  selling_price     unit_cost  \
# count  25099.000000  25099.000000  25099.000000   25099.000000  25099.000000
# mean       1.725686   1136.158014      7.882784    1046.742878    821.274553
# std        0.944941   2976.735689      8.173601    2755.733154   2401.671514
# min        1.000000     80.000000      0.000000      56.000000     40.000000
# 25%        1.000000    160.000000      0.000000     157.500000     80.000000
# 50%        1.000000    280.000000      5.000000     260.000000    140.000000
# 75%        2.000000    500.000000     15.000000     460.000000    240.000000
# max        4.000000  18600.000000     30.000000   18600.000000  14900.000000
#
#        line_total_revenue  line_total_cost
# count        25099.000000     25099.000000
# mean          1806.883900      1420.301606
# std           5519.714864      4818.160051
# min             56.000000        40.000000
# 25%            224.000000       120.000000
# 50%            408.000000       210.000000
# 75%            772.000000       420.000000
# max          74400.000000     59600.000000

# %%
df_dim_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25099 entries, 0 to 25098
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   detail_id           25099 non-null  object
#  1   order_id            25099 non-null  object
#  2   product_id          25099 non-null  object
#  3   quantity            25099 non-null  int64
#  4   unit_price          25099 non-null  int64
#  5   discount_pct        25099 non-null  int64
#  6   selling_price       25099 non-null  float64
#  7   unit_cost           25099 non-null  int64
#  8   line_total_revenue  25099 non-null  float64
#  9   line_total_cost     25099 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 1.9+ MB

# %%
# df_dim_orders['']
