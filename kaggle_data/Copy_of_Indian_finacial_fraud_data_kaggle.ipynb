# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/kaggle_data/Copy_of_Indian_finacial_fraud_data_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
customer_data=pd.read_csv("/content/drive/MyDrive/Indian Financial Fraud Dataset.kaggle/Cusmtomer_data.csv")

# %%
customer_data.head(4)
# Out:
#   Customer_ID   Customer_Name  Gender  Age Marital_Status         Occupation  \
# 0  CUST100001  Omaja Majumdar  Female   27         Single     Police Officer
# 1  CUST100002   Jason Agrawal  Female   41        Married            Teacher
# 2  CUST100003     Amrita Dora    Male   61       Divorsed           Business
# 3  CUST100004   Radhika Batra    Male   26         Single  Software Engineer
#
#    Annual_Income Customer_Segment           State       City Account_Type  \
# 0        1167132             Gold   Uttar Pradesh       Agra      Savings
# 1         493532         Standard  Madhya Pradesh     Ujjain       Salary
# 2        1862614         Platinum           Assam    Silchar      Savings
# 3         808153             Gold   Uttar Pradesh  Ghaziabad       Salary
#
#   Customer_Since
# 0     13-11-2017
# 1     05-05-2020
# 2     23-08-2023
# 3     21-05-2018

# %%
cards_data=pd.read_csv('/content/drive/MyDrive/Indian Financial Fraud Dataset.kaggle/Cards_Data.csv')

# %%
cards_data
# Out:
#           Card_ID Customer_ID Card_Type Card_Network  Credit_Limit  \
# 0      CARD500001  CUST100001      Gold        RuPay        587317
# 1      CARD500002  CUST100002    Silver         Visa        150720
# 2      CARD500003  CUST100003      Gold        RuPay        631005
# 3      CARD500004  CUST100004    Silver   Mastercard        285015
# 4      CARD500005  CUST100005      Gold   Mastercard        348591
# ...           ...         ...       ...          ...           ...
# 32452  CARD532453  CUST124997  Platinum         Visa       1161328
# 32453  CARD532454  CUST124997      Gold        RuPay        557911
# 32454  CARD532455  CUST124998    Silver   Mastercard        265380
# 32455  CARD532456  CUST124999   Classic        RuPay        144707
# 32456  CARD532457  CUST125000  Platinum   Mastercard       1097473
#
#       Card_Status Contactless Card_Mode  Issue_Date Expiry_Date
# 0          Active         Yes  Physical  24-04-2021  24-04-2026
# ...

# %%
transaction_data=pd.read_csv('/content/drive/MyDrive/Indian Financial Fraud Dataset.kaggle/Transaction_Data_250k.csv')

# %%
transaction_data
# Out:
#        Transaction_ID Customer_ID     Card_ID Merchant_ID Transaction_Date  \
# 0          TXN1000001  CUST100660  CARD500875   MER100380       03-03-2024
# 1          TXN1000002  CUST111388  CARD514772   MER100017       08-11-2023
# 2          TXN1000003  CUST115872  CARD520625   MER100143       11-01-2023
# 3          TXN1000004  CUST109049  CARD511773   MER100053       25-05-2023
# 4          TXN1000005  CUST114459  CARD518771   MER100064       22-10-2023
# ...               ...         ...         ...         ...              ...
# 249995     TXN1249996  CUST101141  CARD501484   MER100428       18-05-2026
# 249996     TXN1249997  CUST100211  CARD500270   MER100300       26-02-2026
# 249997     TXN1249998  CUST120491  CARD526607   MER100194       11-05-2026
# 249998     TXN1249999  CUST110885  CARD514128   MER100361       19-10-2023
# 249999     TXN1250000  CUST113764  CARD517861   MER100378       28-08-2025
#
#        Transaction_Time  Transaction_Amount Payment_Method  \
# ...

# %%
merchant_data=pd.read_csv('/content/drive/MyDrive/Indian Financial Fraud Dataset.kaggle/merchant_table.csv')

# %%
merchant_data
# Out:
#     Merchant_ID       Merchant_Name Merchant_Category           State  \
# 0     MER100001     Paytm Utilities         Utilities         Haryana
# 1     MER100002            Coursera         Education           Bihar
# 2     MER100003              Redbus            Travel           Bihar
# 3     MER100004           Air India           Airline      Tamil Nadu
# 4     MER100005              IndiGo           Airline          Punjab
# ..          ...                 ...               ...             ...
# 495   MER100496               IRCTC            Travel           Assam
# 496   MER100497         Apple Store       Electronics  Madhya Pradesh
# 497   MER100498           Tata Cliq         Ecommerce           Bihar
# 498   MER100499  Amazon Prime Video     Entertainment           Assam
# 499   MER100500   MakeMyTrip Hotels             Hotel         Gujarat
#
#             City Merchant_Risk_Level  Merchant_Rating Merchant_Status  \
# ...

# %% [markdown]
# ### **customer_data**

# %%
# dir(customer_data)

# %%
# output_path

# %% [markdown]
# No.of rows and no.of columns in the data

# %%
customer_data.shape
# Out:
# (25000, 12)

# %%
# customer_data.count_values

# %% [markdown]
# Only Age and Annual_Income columns will shows because only these are numeric columns

# %%
customer_data.describe()
# Out:
#                 Age  Annual_Income
# count  25000.000000   2.500000e+04
# mean      41.805840   1.611153e+06
# std       13.062435   1.727786e+06
# min       18.000000   2.000000e+00
# 25%       31.000000   5.704775e+05
# 50%       41.000000   9.691890e+05
# 75%       52.000000   1.882414e+06
# max       70.000000   9.999931e+06

# %% [markdown]
# Getting all the columns

# %%
customer_data.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Gender', 'Age', 'Marital_Status',
#        'Occupation', 'Annual_Income', 'Customer_Segment', 'State', 'City',
#        'Account_Type', 'Customer_Since'],
#       dtype='object')

# %%
# customer_data.customer_ID.count_values()

# %%
# dir(customer_data.customer_ID)

# %%
# help(customer_data['customer_ID'])

# %%
# help(pd.Series)

# %%
# pd.

# %%
display(customer_data.head())
# Out:
#   Customer_ID        Customer_Name  Gender  Age Marital_Status  \
# 0  CUST100001       Omaja Majumdar  Female   27         Single
# 1  CUST100002        Jason Agrawal  Female   41        Married
# 2  CUST100003          Amrita Dora    Male   61       Divorsed
# 3  CUST100004        Radhika Batra    Male   26         Single
# 4  CUST100005  Gautam Mukhopadhyay  Female   24         Single
#
#           Occupation  Annual_Income Customer_Segment           State  \
# 0     Police Officer        1167132             Gold   Uttar Pradesh
# 1            Teacher         493532         Standard  Madhya Pradesh
# 2           Business        1862614         Platinum           Assam
# 3  Software Engineer         808153             Gold   Uttar Pradesh
# 4  Software Engineer        1581447         Platinum       Rajasthan
#
#         City Account_Type Customer_Since
# 0       Agra      Savings     13-11-2017
# 1     Ujjain       Salary     05-05-2020
# 2    Silchar      Savings     23-08-2023
# ...

# %% [markdown]
# The first 5 rows of `customer_data` are shown above. As you indicated in the next cell, we will now look at the number of rows and columns in the DataFrame.

# %% [markdown]
# # Cleaning the data

# %%
customer_data
# Out:
#       Customer_ID        Customer_Name  Gender  Age Marital_Status  \
# 0      CUST100001       Omaja Majumdar  Female   27         Single
# 1      CUST100002        Jason Agrawal  Female   41        Married
# 2      CUST100003          Amrita Dora    Male   61       Divorsed
# 3      CUST100004        Radhika Batra    Male   26         Single
# 4      CUST100005  Gautam Mukhopadhyay  Female   24         Single
# ...           ...                  ...     ...  ...            ...
# 24995  CUST124996          Onveer Kala    Male   22         Single
# 24996  CUST124997          Waida Dewan  Female   29         Single
# 24997  CUST124998          Mohini Devi    Male   48        Married
# 24998  CUST124999          Rishi Bahri    Male   52        Married
# 24999  CUST125000      Chanchal Sarkar  Female   32        Married
#
#                 Occupation  Annual_Income Customer_Segment           State  \
# 0           Police Officer        1167132             Gold   Uttar Pradesh
# ...

# %%
#summing all the columns which has null values
customer_data.isnull().sum()
# Out:
# Customer_ID         0
# Customer_Name       0
# Gender              0
# Age                 0
# Marital_Status      0
# Occupation          0
# Annual_Income       0
# Customer_Segment    0
# State               0
# City                0
# Account_Type        0
# Customer_Since      0
# dtype: int64

# %%
customer_data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
customer_data[customer_data.notnull().all(axis=1)]
# Out:
#       Customer_ID        Customer_Name  Gender  Age Marital_Status  \
# 0      CUST100001       Omaja Majumdar  Female   27         Single
# 1      CUST100002        Jason Agrawal  Female   41        Married
# 2      CUST100003          Amrita Dora    Male   61       Divorsed
# 3      CUST100004        Radhika Batra    Male   26         Single
# 4      CUST100005  Gautam Mukhopadhyay  Female   24         Single
# ...           ...                  ...     ...  ...            ...
# 24995  CUST124996          Onveer Kala    Male   22         Single
# 24996  CUST124997          Waida Dewan  Female   29         Single
# 24997  CUST124998          Mohini Devi    Male   48        Married
# 24998  CUST124999          Rishi Bahri    Male   52        Married
# 24999  CUST125000      Chanchal Sarkar  Female   32        Married
#
#                 Occupation  Annual_Income Customer_Segment           State  \
# 0           Police Officer        1167132             Gold   Uttar Pradesh
# ...

# %% [markdown]
# 2. Count unique values in a specific column of those rows

# %%
customer_data[customer_data.isnull().any(axis=1)]['Customer_ID'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# #performing operations on a single columns

# %%
customer_data['Customer_ID']
# Out:
# 0        CUST100001
# 1        CUST100002
# 2        CUST100003
# 3        CUST100004
# 4        CUST100005
#             ...
# 24995    CUST124996
# 24996    CUST124997
# 24997    CUST124998
# 24998    CUST124999
# 24999    CUST125000
# Name: Customer_ID, Length: 25000, dtype: object

# %%
customer_data['Customer_ID'].value_counts()
# Out:
# Customer_ID
# CUST125000    1
# CUST100001    1
# CUST100002    1
# CUST100003    1
# CUST100004    1
#              ..
# CUST100013    1
# CUST100012    1
# CUST100011    1
# CUST100010    1
# CUST100009    1
# Name: count, Length: 25000, dtype: int64

# %%
# customer_data['Customer_ID'].unique().value_counts()

# %%
customer_data['Customer_ID'].value_counts().sum()
# Out:
# np.int64(25000)

# %%
customer_data['Customer_ID'].unique()
# Out:
# array(['CUST100001', 'CUST100002', 'CUST100003', ..., 'CUST124998',
#        'CUST124999', 'CUST125000'], dtype=object)

# %% [markdown]
# If you want the number of unique Customer_IDs

# %%
customer_data['Customer_ID'].nunique()
# Out:
# 25000

# %%
#It is in python code
len(customer_data['Customer_ID'].unique())
# Out:
# 25000

# %% [markdown]
# Performing operation on State column on customer_data

# %%
customer_data['State']
# Out:
# 0         Uttar Pradesh
# 1        Madhya Pradesh
# 2                 Assam
# 3         Uttar Pradesh
# 4             Rajasthan
#               ...
# 24995            Odisha
# 24996         Karnataka
# 24997       West Bengal
# 24998            Odisha
# 24999            Kerala
# Name: State, Length: 25000, dtype: object

# %%
customer_data['State'].unique()
# Out:
# array(['Uttar Pradesh', 'Madhya Pradesh', 'Assam', 'Rajasthan', 'Haryana',
#        'Maharashtra', 'West Bengal', 'Bihar', 'Punjab', 'Kerala',
#        'Odisha', 'Telangana', 'Gujarat', 'Tamil Nadu', 'Karnataka'],
#       dtype=object)

# %%
customer_data['State'].nunique()
# Out:
# 15

# %%
cards_data.columns
# Out:
# Index(['Card_ID', 'Customer_ID', 'Card_Type', 'Card_Network', 'Credit_Limit',
#        'Card_Status', 'Contactless', 'Card_Mode', 'Issue_Date', 'Expiry_Date'],
#       dtype='object')

# %%
merchant_data.value_counts()
# Out:
# Merchant_ID  Merchant_Name      Merchant_Category  State           City         Merchant_Risk_Level  Merchant_Rating  Merchant_Status  Merchant_Since
# MER100500    MakeMyTrip Hotels  Hotel              Gujarat         Bhavnagar    Medium               3.8              Active           31-01-2017        1
# MER100001    Paytm Utilities    Utilities          Haryana         Gurugram     Medium               4.8              Active           29-07-2012        1
# MER100002    Coursera           Education          Bihar           Patna        Low                  4.3              Active           09-03-2008        1
# MER100003    Redbus             Travel             Bihar           Muzaffarpur  Low                  4.7              Active           12-08-2006        1
# MER100484    HP Lubricants      Fuel               Bihar           Purnia       Low                  4.0              Active           09-06-2014        1
# ...

# %%
len(merchant_data.value_counts())
# Out:
# 500

# %%
merchant_data['Merchant_ID'].nunique()
# Out:
# 500

# %%
cards_data.value_counts()
# Out:
# Card_ID     Customer_ID  Card_Type  Card_Network      Credit_Limit  Card_Status  Contactless  Card_Mode  Issue_Date  Expiry_Date
# CARD532457  CUST125000   Platinum   Mastercard        1097473       Active       Yes          Physical   18-09-2018  18-09-2023     1
# CARD500001  CUST100001   Gold       RuPay             587317        Active       Yes          Physical   24-04-2021  24-04-2026     1
# CARD500002  CUST100002   Silver     Visa              150720        Active       Yes          Virtual    30-06-2020  30-06-2025     1
# CARD500003  CUST100003   Gold       RuPay             631005        Active       Yes          Physical   04-04-2022  04-04-2027     1
# CARD500004  CUST100004   Silver     Mastercard        285015        Expired      Yes          Virtual    21-07-2020  21-07-2025     1
#                                                                                                                                    ..
# ...

# %%
transaction_data.value_counts()
# Out:
# Transaction_ID  Customer_ID  Card_ID     Merchant_ID  Transaction_Date  Transaction_Time  Transaction_Amount  Payment_Method  Transaction_Channel  Device_Type   Transaction_Status  Is_International  Fraud_Flag  Fraud_Reason                                      Merchant_Risk_Level  Merchant_Category  Customer_State  Customer_City  Merchant_State  Merchant_City
# TXN1249958      CUST104783   CARD506213  MER100351    14-03-2025        23:58:07          17791.70            Credit Card     POS                  POS Terminal  Declined            0                 1           Transaction Attempt on Expired Card               Medium               Hospital           Uttar Pradesh   Noida          Bihar           Muzaffarpur      1
# ...

# %%
transaction_data.columns
# Out:
# Index(['Transaction_ID', 'Customer_ID', 'Card_ID', 'Merchant_ID',
#        'Transaction_Date', 'Transaction_Time', 'Transaction_Amount',
#        'Payment_Method', 'Transaction_Channel', 'Device_Type',
#        'Transaction_Status', 'Is_International', 'Fraud_Flag', 'Fraud_Reason',
#        'Merchant_Risk_Level', 'Merchant_Category', 'Customer_State',
#        'Customer_City', 'Merchant_State', 'Merchant_City'],
#       dtype='object')

# %%
transaction_data['Transaction_ID']
# Out:
# 0         TXN1000001
# 1         TXN1000002
# 2         TXN1000003
# 3         TXN1000004
# 4         TXN1000005
#              ...
# 249995    TXN1249996
# 249996    TXN1249997
# 249997    TXN1249998
# 249998    TXN1249999
# 249999    TXN1250000
# Name: Transaction_ID, Length: 250000, dtype: object

# %%
transaction_data['Card_ID'].value_counts()
# Out:
# Card_ID
# CARD509956    26
# CARD523475    21
# CARD529133    21
# CARD530218    20
# CARD515587    19
#               ..
# CARD508516     1
# CARD505971     1
# CARD529299     1
# CARD518602     1
# CARD520496     1
# Name: count, Length: 32292, dtype: int64

# %%
cards_data['Card_ID'].value_counts()
# Out:
# Card_ID
# CARD532457    1
# CARD500001    1
# CARD500002    1
# CARD500003    1
# CARD500004    1
#              ..
# CARD500014    1
# CARD500013    1
# CARD500012    1
# CARD500011    1
# CARD500010    1
# Name: count, Length: 32457, dtype: int64

# %%
cards_data['Card_ID'].nunique()
# Out:
# 32457

# %%
transaction_data.value_counts()
# Out:
# Transaction_ID  Customer_ID  Card_ID     Merchant_ID  Transaction_Date  Transaction_Time  Transaction_Amount  Payment_Method  Transaction_Channel  Device_Type   Transaction_Status  Is_International  Fraud_Flag  Fraud_Reason                                      Merchant_Risk_Level  Merchant_Category  Customer_State  Customer_City  Merchant_State  Merchant_City
# TXN1249958      CUST104783   CARD506213  MER100351    14-03-2025        23:58:07          17791.70            Credit Card     POS                  POS Terminal  Declined            0                 1           Transaction Attempt on Expired Card               Medium               Hospital           Uttar Pradesh   Noida          Bihar           Muzaffarpur      1
# ...

# %%
transaction_data['Transaction_ID'].value_counts()
# Out:
# Transaction_ID
# TXN1249984    1
# TXN1249983    1
# TXN1249982    1
# TXN1249981    1
# TXN1249980    1
#              ..
# TXN1000005    1
# TXN1000004    1
# TXN1000003    1
# TXN1000002    1
# TXN1000001    1
# Name: count, Length: 250000, dtype: int64

# %%
transaction_data
# Out:
#        Transaction_ID Customer_ID     Card_ID Merchant_ID Transaction_Date  \
# 0          TXN1000001  CUST100660  CARD500875   MER100380       03-03-2024
# 1          TXN1000002  CUST111388  CARD514772   MER100017       08-11-2023
# 2          TXN1000003  CUST115872  CARD520625   MER100143       11-01-2023
# 3          TXN1000004  CUST109049  CARD511773   MER100053       25-05-2023
# 4          TXN1000005  CUST114459  CARD518771   MER100064       22-10-2023
# ...               ...         ...         ...         ...              ...
# 249995     TXN1249996  CUST101141  CARD501484   MER100428       18-05-2026
# 249996     TXN1249997  CUST100211  CARD500270   MER100300       26-02-2026
# 249997     TXN1249998  CUST120491  CARD526607   MER100194       11-05-2026
# 249998     TXN1249999  CUST110885  CARD514128   MER100361       19-10-2023
# 249999     TXN1250000  CUST113764  CARD517861   MER100378       28-08-2025
#
#        Transaction_Time  Transaction_Amount Payment_Method  \
# ...

# %%
transaction_data['Transaction_ID'].nunique()
# Out:
# 250000

# %%
transaction_data.isnull().sum()
# Out:
# Transaction_ID              0
# Customer_ID                 0
# Card_ID                     0
# Merchant_ID                 0
# Transaction_Date            0
# Transaction_Time            0
# Transaction_Amount          0
# Payment_Method              0
# Transaction_Channel         0
# Device_Type                 0
# Transaction_Status          0
# Is_International            0
# Fraud_Flag                  0
# Fraud_Reason           236527
# Merchant_Risk_Level         0
# Merchant_Category           0
# Customer_State              0
# Customer_City               0
# Merchant_State              0
# Merchant_City               0
# dtype: int64

# %%
transaction_data.columns
# Out:
# Index(['Transaction_ID', 'Customer_ID', 'Card_ID', 'Merchant_ID',
#        'Transaction_Date', 'Transaction_Time', 'Transaction_Amount',
#        'Payment_Method', 'Transaction_Channel', 'Device_Type',
#        'Transaction_Status', 'Is_International', 'Fraud_Flag', 'Fraud_Reason',
#        'Merchant_Risk_Level', 'Merchant_Category', 'Customer_State',
#        'Customer_City', 'Merchant_State', 'Merchant_City'],
#       dtype='object')

# %%
transaction_data.columns.nunique()
# Out:
# 20

# %% [markdown]
# NO.of Unique values in the columns

# %%
transaction_data.nunique()
# Out:
# Transaction_ID         250000
# Customer_ID             24902
# Card_ID                 32292
# Merchant_ID               500
# Transaction_Date         1325
# Transaction_Time        81562
# Transaction_Amount     178189
# Payment_Method              4
# Transaction_Channel         4
# Device_Type                 6
# Transaction_Status          3
# Is_International            2
# Fraud_Flag                  2
# Fraud_Reason                8
# Merchant_Risk_Level         3
# Merchant_Category          15
# Customer_State             15
# Customer_City              85
# Merchant_State             15
# Merchant_City              85
# dtype: int64

# %%
transaction_data['Merchant_Risk_Level'].value_counts()
# Out:
# Merchant_Risk_Level
# Low       154896
# Medium     64366
# High       30738
# Name: count, dtype: int64

# %%
transaction_data['Merchant_Risk_Level'].max()
# Out:
# 'Medium'

# %%
transaction_data['Transaction_Status'].value_counts()
# Out:
# Transaction_Status
# Successful    227821
# Declined       12010
# Failed         10169
# Name: count, dtype: int64
