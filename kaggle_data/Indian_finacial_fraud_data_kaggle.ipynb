# %% [markdown]
# <a href="https://colab.research.google.com/github/Addakularanjith123/Practice-sql/blob/main/kaggle_data/Indian_finacial_fraud_data_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np

# %%
customer_data=pd.read_csv("/content/drive/MyDrive/Indian Financial Fraud Dataset.kaggle/Cusmtomer_data.csv")

# %%
customer_data.head(4)

# %%
cards_data=pd.read_csv('/content/drive/MyDrive/Indian Financial Fraud Dataset.kaggle/Cards_Data.csv')

# %%
cards_data

# %%
transaction_data=pd.read_csv('/content/drive/MyDrive/Indian Financial Fraud Dataset.kaggle/Transaction_Data_250k.csv')

# %%
transaction_data

# %%
merchan_data=pd.read_csv('/content/drive/MyDrive/Indian Financial Fraud Dataset.kaggle/merchant_table.csv')

# %%
merchan_data
